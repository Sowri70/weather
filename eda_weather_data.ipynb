# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\Rajan\Desktop\weather\weather_data.csv")

# %%
df
# Out:
#      Unnamed: 0  Ozone  Solar.R  Wind Temp C Month  Day  Year  Temp Weather
# 0             1   41.0    190.0   7.4     67     5    1  2025    67       S
# 1             2   36.0    118.0   8.0     72     5    2  2025    72       C
# 2             3   12.0    149.0  12.6     74     5    3  2025    74      PS
# 3             4   18.0    313.0  11.5     62     5    4  2025    62       S
# 4             5    NaN      NaN  14.3     56     5    5  2025    56       S
# ..          ...    ...      ...   ...    ...   ...  ...   ...   ...     ...
# 156         155   30.0    193.0   6.9     70     9   26  2025    70      PS
# 157         156    NaN    145.0  13.2     77     9   27  2025    77       S
# 158         157   14.0    191.0  14.3     75     9   28  2025    75       S
# 159         158   18.0    131.0   8.0     76     9   29  2025    76       C
# 160         158   18.0    131.0   8.0     76     9   29  2025    76       C
#
# [161 rows x 10 columns]

# %%
df.shape
# Out:
# (161, 10)

# %%
df.head(10)
# Out:
#    Unnamed: 0  Ozone  Solar.R  Wind Temp C Month  Day  Year  Temp Weather
# 0           1   41.0    190.0   7.4     67     5    1  2025    67       S
# 1           2   36.0    118.0   8.0     72     5    2  2025    72       C
# 2           3   12.0    149.0  12.6     74     5    3  2025    74      PS
# 3           4   18.0    313.0  11.5     62     5    4  2025    62       S
# 4           5    NaN      NaN  14.3     56     5    5  2025    56       S
# 5           6   28.0      NaN  14.9     66     5    6  2025    66       C
# 6           7   23.0    299.0   8.6     65     5    7  2025    65      PS
# 7           8   19.0     99.0  13.8     59     5    8  2025    59       C
# 8           9    8.0     19.0  20.1     61     5    9  2025    61      PS
# 9          10    NaN    194.0   8.6     69     5   10  2025    69       S

# %%
df.dtypes
# Out:
# Unnamed: 0      int64
# Ozone         float64
# Solar.R       float64
# Wind          float64
# Temp C         object
# Month          object
# Day             int64
# Year            int64
# Temp            int64
# Weather        object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 161 entries, 0 to 160
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  161 non-null    int64
#  1   Ozone       123 non-null    float64
#  2   Solar.R     154 non-null    float64
#  3   Wind        161 non-null    float64
#  4   Temp C      161 non-null    object
#  5   Month       161 non-null    object
#  6   Day         161 non-null    int64
#  7   Year        161 non-null    int64
#  8   Temp        161 non-null    int64
#  9   Weather     158 non-null    object
# dtypes: float64(3), int64(4), object(3)
# memory usage: 12.7+ KB

# %%
df.describe()
# Out:
#        Unnamed: 0       Ozone     Solar.R        Wind         Day    Year  \
# count  161.000000  123.000000  154.000000  161.000000  161.000000   161.0
# mean    80.391304   41.837398  185.642857    9.903106   15.950311  2025.0
# std     46.121738   32.674343   88.237623    3.503274    9.066285     0.0
# min      1.000000    1.000000    7.000000    1.700000    1.000000  2025.0
# 25%     41.000000   18.000000  121.750000    7.400000    8.000000  2025.0
# 50%     80.000000   31.000000  195.500000    9.700000   16.000000  2025.0
# 75%    120.000000   62.000000  257.500000   11.500000   24.000000  2025.0
# max    158.000000  168.000000  334.000000   20.700000   31.000000  2025.0
#
#              Temp
# count  161.000000
# mean    77.739130
# std      9.397155
# min     56.000000
# 25%     72.000000
# 50%     78.000000
# 75%     84.000000
# max     97.000000

# %%
df.describe(include='object')
# Out:
#        Temp C Month Weather
# count     161   161     158
# unique     41     6       3
# top        81     9       S
# freq       11    35      59

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 156    False
# 157    False
# 158    False
# 159    False
# 160     True
# Length: 161, dtype: bool

# %%
df.loc[df.duplicated()]
# Out:
#      Unnamed: 0  Ozone  Solar.R  Wind Temp C Month  Day  Year  Temp Weather
# 84           70   97.0    272.0   5.7     92     7    9  2025    92       C
# 155         154   41.0    190.0   7.4     67     5    1  2025    67       C
# 160         158   18.0    131.0   8.0     76     9   29  2025    76       C

# %%
df.drop_duplicates(ignore_index=True)
# Out:
#      Unnamed: 0  Ozone  Solar.R  Wind Temp C Month  Day  Year  Temp Weather
# 0             1   41.0    190.0   7.4     67     5    1  2025    67       S
# 1             2   36.0    118.0   8.0     72     5    2  2025    72       C
# 2             3   12.0    149.0  12.6     74     5    3  2025    74      PS
# 3             4   18.0    313.0  11.5     62     5    4  2025    62       S
# 4             5    NaN      NaN  14.3     56     5    5  2025    56       S
# ..          ...    ...      ...   ...    ...   ...  ...   ...   ...     ...
# 153         154   41.0    190.0   7.4     67     5    1  2025    67       C
# 154         155   30.0    193.0   6.9     70     9   26  2025    70      PS
# 155         156    NaN    145.0  13.2     77     9   27  2025    77       S
# 156         157   14.0    191.0  14.3     75     9   28  2025    75       S
# 157         158   18.0    131.0   8.0     76     9   29  2025    76       C
#
# [158 rows x 10 columns]

# %%
df = df.drop_duplicates(ignore_index=True)

# %%
df
# Out:
#      Unnamed: 0  Ozone  Solar.R  Wind Temp C Month  Day  Year  Temp Weather
# 0             1   41.0    190.0   7.4     67     5    1  2025    67       S
# 1             2   36.0    118.0   8.0     72     5    2  2025    72       C
# 2             3   12.0    149.0  12.6     74     5    3  2025    74      PS
# 3             4   18.0    313.0  11.5     62     5    4  2025    62       S
# 4             5    NaN      NaN  14.3     56     5    5  2025    56       S
# ..          ...    ...      ...   ...    ...   ...  ...   ...   ...     ...
# 153         154   41.0    190.0   7.4     67     5    1  2025    67       C
# 154         155   30.0    193.0   6.9     70     9   26  2025    70      PS
# 155         156    NaN    145.0  13.2     77     9   27  2025    77       S
# 156         157   14.0    191.0  14.3     75     9   28  2025    75       S
# 157         158   18.0    131.0   8.0     76     9   29  2025    76       C
#
# [158 rows x 10 columns]

# %%
df.drop(["Unnamed: 0", "Temp C"], axis = 1)
# Out:
#      Ozone  Solar.R  Wind Month  Day  Year  Temp Weather
# 0     41.0    190.0   7.4     5    1  2025    67       S
# 1     36.0    118.0   8.0     5    2  2025    72       C
# 2     12.0    149.0  12.6     5    3  2025    74      PS
# 3     18.0    313.0  11.5     5    4  2025    62       S
# 4      NaN      NaN  14.3     5    5  2025    56       S
# ..     ...      ...   ...   ...  ...   ...   ...     ...
# 153   41.0    190.0   7.4     5    1  2025    67       C
# 154   30.0    193.0   6.9     9   26  2025    70      PS
# 155    NaN    145.0  13.2     9   27  2025    77       S
# 156   14.0    191.0  14.3     9   28  2025    75       S
# 157   18.0    131.0   8.0     9   29  2025    76       C
#
# [158 rows x 8 columns]

# %%
df = df.drop(["Unnamed: 0", "Temp C"], axis = 1)

# %%
 df = df.rename({"Solar.R":"Solar"}, axis = 1)

# %%
df
# Out:
#      Ozone  Solar  Wind Month  Day  Year  Temp Weather
# 0     41.0  190.0   7.4     5    1  2025    67       S
# 1     36.0  118.0   8.0     5    2  2025    72       C
# 2     12.0  149.0  12.6     5    3  2025    74      PS
# 3     18.0  313.0  11.5     5    4  2025    62       S
# 4      NaN    NaN  14.3     5    5  2025    56       S
# ..     ...    ...   ...   ...  ...   ...   ...     ...
# 153   41.0  190.0   7.4     5    1  2025    67       C
# 154   30.0  193.0   6.9     9   26  2025    70      PS
# 155    NaN  145.0  13.2     9   27  2025    77       S
# 156   14.0  191.0  14.3     9   28  2025    75       S
# 157   18.0  131.0   8.0     9   29  2025    76       C
#
# [158 rows x 8 columns]

# %%
df.isna().sum()
# Out:
# Ozone      38
# Solar       7
# Wind        0
# Month       0
# Day         0
# Year        0
# Temp        0
# Weather     3
# dtype: int64

# %%
df["Solar"].mean().round()
# Out:
# np.float64(185.0)

# %%
mean = df["Solar"].mean().round()

# %%
df["Solar"].fillna(mean)
# Out:
# 0      190.0
# 1      118.0
# 2      149.0
# 3      313.0
# 4      185.0
#        ...
# 153    190.0
# 154    193.0
# 155    145.0
# 156    191.0
# 157    131.0
# Name: Solar, Length: 158, dtype: float64

# %%
df["Solar"] = df["Solar"].fillna(mean)

# %%
df
# Out:
#      Ozone  Solar  Wind Month  Day  Year  Temp Weather
# 0     41.0  190.0   7.4     5    1  2025    67       S
# 1     36.0  118.0   8.0     5    2  2025    72       C
# 2     12.0  149.0  12.6     5    3  2025    74      PS
# 3     18.0  313.0  11.5     5    4  2025    62       S
# 4      NaN  185.0  14.3     5    5  2025    56       S
# ..     ...    ...   ...   ...  ...   ...   ...     ...
# 153   41.0  190.0   7.4     5    1  2025    67       C
# 154   30.0  193.0   6.9     9   26  2025    70      PS
# 155    NaN  145.0  13.2     9   27  2025    77       S
# 156   14.0  191.0  14.3     9   28  2025    75       S
# 157   18.0  131.0   8.0     9   29  2025    76       C
#
# [158 rows x 8 columns]

# %%
df["Month"].unique()
# Out:
# array(['5', 'May', '6', '7', '8', '9'], dtype=object)

# %%
df["Month"].replace({"May":'5'}).unique()
# Out:
# array(['5', '6', '7', '8', '9'], dtype=object)

# %%
df
# Out:
#      Ozone  Solar  Wind Month  Day  Year  Temp Weather
# 0     41.0  190.0   7.4     5    1  2025    67       S
# 1     36.0  118.0   8.0     5    2  2025    72       C
# 2     12.0  149.0  12.6     5    3  2025    74      PS
# 3     18.0  313.0  11.5     5    4  2025    62       S
# 4      NaN  185.0  14.3     5    5  2025    56       S
# ..     ...    ...   ...   ...  ...   ...   ...     ...
# 153   41.0  190.0   7.4     5    1  2025    67       C
# 154   30.0  193.0   6.9     9   26  2025    70      PS
# 155    NaN  145.0  13.2     9   27  2025    77       S
# 156   14.0  191.0  14.3     9   28  2025    75       S
# 157   18.0  131.0   8.0     9   29  2025    76       C
#
# [158 rows x 8 columns]

# %%
df["Month"] = df["Month"].replace({"May":'5'})

# %%
df
# Out:
#      Ozone  Solar  Wind Month  Day  Year  Temp Weather
# 0     41.0  190.0   7.4     5    1  2025    67       S
# 1     36.0  118.0   8.0     5    2  2025    72       C
# 2     12.0  149.0  12.6     5    3  2025    74      PS
# 3     18.0  313.0  11.5     5    4  2025    62       S
# 4      NaN  185.0  14.3     5    5  2025    56       S
# ..     ...    ...   ...   ...  ...   ...   ...     ...
# 153   41.0  190.0   7.4     5    1  2025    67       C
# 154   30.0  193.0   6.9     9   26  2025    70      PS
# 155    NaN  145.0  13.2     9   27  2025    77       S
# 156   14.0  191.0  14.3     9   28  2025    75       S
# 157   18.0  131.0   8.0     9   29  2025    76       C
#
# [158 rows x 8 columns]

# %%
df["Date"] = pd.to_datetime(df[["Year", "Month", "Day"]])

# %%
df
# Out:
#      Ozone  Solar  Wind Month  Day  Year  Temp Weather       Date
# 0     41.0  190.0   7.4     5    1  2025    67       S 2025-05-01
# 1     36.0  118.0   8.0     5    2  2025    72       C 2025-05-02
# 2     12.0  149.0  12.6     5    3  2025    74      PS 2025-05-03
# 3     18.0  313.0  11.5     5    4  2025    62       S 2025-05-04
# 4      NaN  185.0  14.3     5    5  2025    56       S 2025-05-05
# ..     ...    ...   ...   ...  ...   ...   ...     ...        ...
# 153   41.0  190.0   7.4     5    1  2025    67       C 2025-05-01
# 154   30.0  193.0   6.9     9   26  2025    70      PS 2025-09-26
# 155    NaN  145.0  13.2     9   27  2025    77       S 2025-09-27
# 156   14.0  191.0  14.3     9   28  2025    75       S 2025-09-28
# 157   18.0  131.0   8.0     9   29  2025    76       C 2025-09-29
#
# [158 rows x 9 columns]

# %%
df.boxplot(column="Ozone")
# Out:
# <Axes: >

# %%
df["Ozone"].describe()
# Out:
# count    120.000000
# mean      41.583333
# std       32.620709
# min        1.000000
# 25%       18.000000
# 50%       30.500000
# 75%       61.500000
# max      168.000000
# Name: Ozone, dtype: float64

# %%
IQR = 61.5000000 - 18.000000
max_limit = 61.5000000  + 1.5 * IQR
max_limit
# Out:
# 126.75

# %%
df["Ozone"] > max_limit
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 153    False
# 154    False
# 155    False
# 156    False
# 157    False
# Name: Ozone, Length: 158, dtype: bool

# %%
df[df["Ozone"] > max_limit]
# Out:
#      Ozone  Solar  Wind Month  Day  Year  Temp Weather       Date
# 61   135.0  269.0   4.1     7    1  2025    84       S 2025-07-01
# 116  168.0  238.0   3.4     8   25  2025    81      PS 2025-08-25

# %%
df.dtypes
# Out:
# Ozone             float64
# Solar             float64
# Wind              float64
# Month              object
# Day                 int64
# Year                int64
# Temp                int64
# Weather            object
# Date       datetime64[ns]
# dtype: object

# %%
df["Weather"].value_counts().plot(kind='bar')
plt.show()

# %%
df["Month"].value_counts().plot(kind='bar')
plt.show()

# %%
# Mean, Median, Mode, Variance, Skewness, Kurtosis

# %%
df.columns
# Out:
# Index(['Ozone', 'Solar', 'Wind', 'Month', 'Day', 'Year', 'Temp', 'Weather',
#        'Date'],
#       dtype='object')

# %%
df.var(numeric_only=True)
# Out:
# Ozone    1064.110644
# Solar    7520.824518
# Wind       12.328955
# Day        80.949004
# Year        0.000000
# Temp       87.944570
# dtype: float64

# %%
df.skew(numeric_only=True)
# Out:
# Ozone    1.282000
# Solar   -0.425459
# Wind     0.349332
# Day     -0.036407
# Year     0.000000
# Temp    -0.340108
# dtype: float64

# %%
df["Solar"].plot(kind='hist',bins=20)
plt.show()

# %%
df["Wind"].plot(kind='hist',bins=20)
plt.show()

# %%
df["Wind"].plot(kind='kde')
plt.show()

# %%
df.boxplot(column="Ozone", vert=False)
plt.show()

# %%
df.boxplot(column="Wind")
plt.show()

# %%
sns.displot(data=df, x='Solar', kind='hist', kde=True)
plt.show()

# %%
sns.violinplot(data=df, x="Solar")
plt.show()

# %%
df.plot(kind="scatter", x="Ozone", y="Temp")
plt.show()

# %%
sns.scatterplot(data=df, x="Ozone", y="Temp", hue="Weather")
plt.show()

# %%
df1 = df.drop(["Year"], axis=1)
df1
# Out:
#      Ozone  Solar  Wind Month  Day  Temp Weather       Date
# 0     41.0  190.0   7.4     5    1    67       S 2025-05-01
# 1     36.0  118.0   8.0     5    2    72       C 2025-05-02
# 2     12.0  149.0  12.6     5    3    74      PS 2025-05-03
# 3     18.0  313.0  11.5     5    4    62       S 2025-05-04
# 4      NaN  185.0  14.3     5    5    56       S 2025-05-05
# ..     ...    ...   ...   ...  ...   ...     ...        ...
# 153   41.0  190.0   7.4     5    1    67       C 2025-05-01
# 154   30.0  193.0   6.9     9   26    70      PS 2025-09-26
# 155    NaN  145.0  13.2     9   27    77       S 2025-09-27
# 156   14.0  191.0  14.3     9   28    75       S 2025-09-28
# 157   18.0  131.0   8.0     9   29    76       C 2025-09-29
#
# [158 rows x 8 columns]

# %%
sns.pairplot(data=df1, hue="Weather")
plt.show()

# %%
df1.corr(numeric_only=True)
# Out:
#           Ozone     Solar      Wind       Day      Temp
# Ozone  1.000000  0.344013 -0.593530 -0.035055  0.694098
# Solar  0.344013  1.000000 -0.055036 -0.149447  0.260577
# Wind  -0.593530 -0.055036  1.000000  0.040151 -0.441247
# Day   -0.035055 -0.149447  0.040151  1.000000 -0.124538
# Temp   0.694098  0.260577 -0.441247 -0.124538  1.000000

# %%
sns.heatmap(df1.corr(numeric_only=True), annot =True)
plt.show()

# %%
sns.boxplot(data = df, x="Ozone", y="Weather")
plt.show()

# %%
df
# Out:
#      Ozone  Solar  Wind Month  Day  Year  Temp Weather       Date
# 0     41.0  190.0   7.4     5    1  2025    67       S 2025-05-01
# 1     36.0  118.0   8.0     5    2  2025    72       C 2025-05-02
# 2     12.0  149.0  12.6     5    3  2025    74      PS 2025-05-03
# 3     18.0  313.0  11.5     5    4  2025    62       S 2025-05-04
# 4      NaN  185.0  14.3     5    5  2025    56       S 2025-05-05
# ..     ...    ...   ...   ...  ...   ...   ...     ...        ...
# 153   41.0  190.0   7.4     5    1  2025    67       C 2025-05-01
# 154   30.0  193.0   6.9     9   26  2025    70      PS 2025-09-26
# 155    NaN  145.0  13.2     9   27  2025    77       S 2025-09-27
# 156   14.0  191.0  14.3     9   28  2025    75       S 2025-09-28
# 157   18.0  131.0   8.0     9   29  2025    76       C 2025-09-29
#
# [158 rows x 9 columns]

# %%
sns.lineplot(data=df, x="Date", y="Temp")
plt.show()

# %%
pd.crosstab(df["Month"], df["Weather"])
# Out:
# Weather   C  PS   S
# Month
# 5        11   9  12
# 6         9   9  12
# 7        11   8  11
# 8        10   8  11
# 9         8  13  13

# %%
df.groupby("Weather") [["Ozone", "Wind"]].mean(numeric_only=True)
# Out:
#              Ozone       Wind
# Weather
# C        46.162162   9.783673
# PS       42.194444   9.908511
# S        36.909091  10.093220

# %%
df.groupby("Weather") [["Ozone", "Wind"]].describe()
# Out:
#         Ozone                                                       Wind  \
#         count       mean        std  min   25%   50%    75%    max count
# Weather
# C        37.0  46.162162  32.593041  6.0  22.0  37.0  65.00  122.0  49.0
# PS       36.0  42.194444  37.225045  4.0  16.0  29.5  67.50  168.0  47.0
# S        44.0  36.909091  28.789386  1.0  15.5  28.0  45.25  135.0  59.0
#
#
#               mean       std  min  25%   50%    75%   max
# Weather
# C         9.783673  3.869450  1.7  7.4   9.7  11.50  20.7
# PS        9.908511  3.612348  3.4  7.4   9.2  12.05  20.1
# S        10.093220  3.177880  2.3  7.4  10.3  11.75  15.5

# %% [markdown]
# # Ask Questions on DataFrame?
#
# # Indexing and retrieving Data

# %%
# What are average values of numerical features for Sunny Weather ?

df[df["Ozone"] > 41.0].sort_values(by="Temp", ascending=False)
# Out:
#      Ozone  Solar  Wind Month  Day  Year  Temp Weather       Date
# 119   76.0  203.0   9.7     8   28  2025    97       S 2025-08-28
# 121   84.0  237.0   6.3     8   30  2025    96       S 2025-08-30
# 120  118.0  225.0   2.3     8   29  2025    94       S 2025-08-29
# 122   85.0  188.0   6.3     8   31  2025    94       C 2025-08-31
# 125   73.0  183.0   2.8     9    3  2025    93       C 2025-09-03
# 126   91.0  189.0   4.6     9    4  2025    93      PS 2025-09-04
# 69    97.0  272.0   5.7     7    9  2025    92       C 2025-07-09
# 124   78.0  197.0   5.1     9    2  2025    92      PS 2025-09-02
# 68    97.0  267.0   6.3     7    8  2025    92      PS 2025-07-08
# 123   96.0  167.0   6.9     9    1  2025    91       C 2025-09-01
# 39    71.0  291.0  13.8     6    9  2025    90       S 2025-06-09
# 99    89.0  229.0  10.3     8    8  2025    90      PS 2025-08-08
# 100  110.0  207.0   8.0     8    9  2025    90       C 2025-08-09
# 70    85.0  175.0   7.4     7   10  2025    89      PS 2025-07-10
# 98   122.0  255.0   4.0     8    7  2025    89       C 2025-08-07
# 88    82.0  213.0   7.4     7   28  2025    88       S 2025-07-28
# 67    77.0  276.0   5.1     7    7  2025    88       C 2025-07-07
# 97    66.0  185.0   4.6     8    6  2025    87       C 2025-08-06
# 127   47.0   95.0   7.4     9    5  2025    87       S 2025-09-05
# 79    79.0  187.0   5.1     7   19  2025    87      PS 2025-07-19
# 84    80.0  294.0   8.6     7   24  2025    86      PS 2025-07-24
# 117   73.0  215.0   8.0     8   26  2025    86       S 2025-08-26
# 95    78.0  185.0   6.9     8    4  2025    86     NaN 2025-08-04
# 103   44.0  192.0  11.5     8   12  2025    86       S 2025-08-12
# 89    50.0  275.0   7.4     7   29  2025    86       C 2025-07-29
# 87    52.0   82.0  12.0     7   27  2025    86     NaN 2025-07-27
# 62    49.0  248.0   9.2     7    2  2025    85       C 2025-07-02
# 80    63.0  220.0  11.5     7   20  2025    85       C 2025-07-20
# 85   108.0  223.0   8.0     7   25  2025    85      PS 2025-07-25
# 61   135.0  269.0   4.1     7    1  2025    84       S 2025-07-01
# 78    61.0  285.0   6.3     7   18  2025    84       C 2025-07-18
# 65    64.0  175.0   4.6     7    5  2025    83       S 2025-07-05
# 90    64.0  253.0   7.4     7   30  2025    83      PS 2025-07-30
# 133   44.0  236.0  14.9     9   11  2025    81      PS 2025-09-11
# 28    45.0  252.0  14.9     5   29  2025    81       S 2025-05-29
# 76    48.0  260.0   6.9     7   16  2025    81       S 2025-07-16
# 116  168.0  238.0   3.4     8   25  2025    81      PS 2025-08-25
# 91    59.0  254.0   9.2     7   31  2025    81       C 2025-07-31
# 105   65.0  157.0   9.7     8   14  2025    80       C 2025-08-14
# 29   115.0  223.0   5.7     5   30  2025    79       C 2025-05-30
# 108   59.0   51.0   6.3     8   17  2025    79      PS 2025-08-17
# 115   45.0  212.0   9.7     8   24  2025    79       C 2025-08-24
# 111   44.0  190.0  10.3     8   20  2025    78       S 2025-08-20
# 138   46.0  237.0   6.9     9   16  2025    78       S 2025-09-16

# %%
# What are average values of numerical features for Sunny Weather ?
df[df["Weather"] =='S'].mean(numeric_only=True)
# Out:
# Ozone      36.909091
# Solar     193.050847
# Wind       10.093220
# Day        16.661017
# Year     2025.000000
# Temp       78.067797
# dtype: float64

# %%
# What is the average temperature during the month of June when the weather is cloudy?

df[(df["Month"] == '6')&(df["Weather"] == 'C')]["Temp"].mean().round()
# Out:
# np.float64(78.0)

# %%
# What is the maximum wind speed during July when day is sunny?
df[(df["Weather"] == 'S')&(df["Month"] == '7')]["Wind"].max()
# Out:
# 14.9

# %%
df.columns
# Out:
# Index(['Ozone', 'Solar', 'Wind', 'Month', 'Day', 'Year', 'Temp', 'Weather',
#        'Date'],
#       dtype='object')

# %%
df.head(5)
# Out:
#    Ozone  Solar  Wind Month  Day  Year  Temp Weather       Date
# 0   41.0  190.0   7.4     5    1  2025    67       S 2025-05-01
# 1   36.0  118.0   8.0     5    2  2025    72       C 2025-05-02
# 2   12.0  149.0  12.6     5    3  2025    74      PS 2025-05-03
# 3   18.0  313.0  11.5     5    4  2025    62       S 2025-05-04
# 4    NaN  185.0  14.3     5    5  2025    56       S 2025-05-05

# %%
max_wind = df[(df["Weather"] == "S") & (df["Month"] == '9')]["Wind"].max()
print(max_wind)
# Out:
# 15.5
